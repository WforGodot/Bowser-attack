# %%
import pytesseract
from PIL import Image

# If you have a path to an image file
image_path = '9.png'
image = Image.open(image_path)

# Use Tesseract to do OCR on the image
text = pytesseract.image_to_string(image)

print(text)
# Out:
# @ Filippo Berio Classic Green Pesto X +
#
# qd Cc
#
# AMAZON cou
#
# = All Today's Deals
#
# Grocery Best Sellers
#
# « Back to results
#
# VIDEO
#
# Q
#
# iver to We
#
# © oxford 0x14
#
# Morrisons
#
# Special Offers
#
# @ amazon.co.uk/Filippo-Berio-Classic-Green-Pesto/dp/B01BMMZHPM/ref=sr_1_8?crid=3751Q2858KHF2&keywords=pesto&qid=16742288... 12 | PA
#
# Hello, Dert Returns
# All pesto BH ~- Account &Lists~ & Orders
#
# Free Delivery Buy Again
#
# Luxury Food & Drink
#
# Gift Cards & Top Up Amazon Business ~ Vouchers GiftIdeas Shopper Toolkit Beauty Fashion Toys & Games
#
# Beverages
#
# Chocolate & Sweets
#
# Snacks
#
# a
#
# Baby Food ~ Food Cupboard Speciality Diets“ Household
#
# Filippo Berio Classic Green Pesto 190gr
#
# Buying for work? Discover Amazon Business, for business-exclusive pricing, downloadable VAT
# invoices and more. Create a FREE account
#
# Brand: Filippo Berio
# toto tet ~ 242 ratings
#
# Flavour Pesto
#
# Brand Filippo Berio
#
# Package Jar
#
# information
#
# Item weight 190 Grams
#
# Allergen Contains: Milk, Cashews
# information
#
# v See more
#
# About this item
#
# * Produced in Linguria, Italy, the Home of Pesto.“This versatile clas:
# bursting with the taste of Italian Basil.“For 4 servings, stir a jar of Filippo
# Berio Classic Pesto into 500g of freshly cooked pasta.
#
# » See more product details
#
# EE) Report incorrect product information.
#
# Health & Personal Care Home & Garden
#
# © Deliver to Wen - Oxford OX1 4
#
# See All Buying Options
#
# | Add to List v|
#
# Have one to sell?
#
# Sell on Amazon

# %%
import pytesseract
from PIL import Image, ImageDraw, ImageFont

def annotate_image_with_text(image_path, output_path, confidence_threshold=60):
    # Load the image
    image = Image.open(image_path)
    draw = ImageDraw.Draw(image)

    # Optionally, if you want to use a specific font, provide the font path and size
    # font = ImageFont.truetype("path_to_font.ttf", size=12)
    
    # Use Tesseract to do OCR on the image and get bounding box information
    data = pytesseract.image_to_data(image, output_type=pytesseract.Output.DICT)

    # Iterate through each text element
    for i in range(len(data['text'])):
        # Only consider elements with confidence greater than the threshold
        if int(data['conf'][i]) > confidence_threshold:
            # Extract coordinates
            x, y, w, h = (data['left'][i], data['top'][i], data['width'][i], data['height'][i])
            text = data['text'][i]
            
            # Draw the bounding box
            draw.rectangle([x, y, x + w, y + h], outline='red')
            
            # Draw the text
            # If you have a specific font, replace `font=None` with `font=font`
            draw.text((x, y - 10), text, fill='red', font=None)

    # Save the annotated image
    image.save(output_path)

# Example usage:
# annotate_image_with_text('path_to_your_image.jpg', 'path_to_save_annotated_image.jpg')

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Example for Windows

# %%
annotate_image_with_text('9.png', '9_annotated.png')
